# %%
import pandas as pd
import requests

# %%
# read keys
import yaml
import os

def read_config():
    # Get the directory of the current script
    # script_dir = os.path.dirname(os.path.realpath(__file__))
    script_dir = "../src/"

    # Construct the full path to the configuration file
    file_path = os.path.join(script_dir, "apikeys.yml")

    with open(file_path, 'r') as stream:
        try:
            configs = yaml.safe_load(stream)
            api_key = configs['amadeues_flights']['api_key']
            api_secret = configs['amadeues_flights']['api_secret']
            return api_key, api_secret
        except yaml.YAMLError as exc:
            print(exc)
            
    return api_key, api_secret


class SingletonToken:
    __token = None

    @classmethod
    def set_token(cls, token):
        cls.__token = token

    @classmethod
    def get_token(cls):
        return cls.__token

api_key, api_secret = read_config()

# %%
from amadeus import Client, ResponseError

amadeus = Client(client_id=api_key, client_secret=api_secret)

# Defining the parameters for the flight
params = {
    'originLocationCode': 'SYD',
    'destinationLocationCode': 'BKK',
    'departureDate': '2023-10-10',
    'adults': 1
    # add or modify other parameters according to your needs
}

try:
    response_flights = amadeus.shopping.flight_offers_search.get(**params)
    
except ResponseError as error:
    print(f"ResponseError occurred: {error}")
    print(f"Error code: {error.code}")
    print(f"Error message: {error.description}")


try:
    response_airline_lookup = amadeus.reference_data.airlines.get()

    
except ResponseError as error:
    print(f"ResponseError occurred: {error}")
    print(f"Error code: {error.code}")
    print(f"Error message: {error.description}")

# %%
flights_data = response_flights.data
df_flights = pd.json_normalize(response_flights.data)
df_airline_codes = pd.json_normalize(response_airline_lookup.data)

# %%
import langchain
from langchain.agents.agent_toolkits import create_python_agent
from langchain.tools.python.tool import PythonREPLTool
from langchain.python import PythonREPL
from langchain.llms.openai import OpenAI
from langchain.agents.agent_types import AgentType
from langchain.chat_models import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI
from langchain.experimental.plan_and_execute import PlanAndExecute, load_agent_executor, load_chat_planner
from langchain.tools.python.tool import PythonREPLTool
from langchain.llms import OpenAI
from langchain import SerpAPIWrapper
from langchain.agents.tools import Tool
from langchain import LLMMathChain

# %%
from amadeus import Client, ResponseError
from datetime import datetime
from langchain.chat_models import ChatOpenAI
from langchain.experimental.plan_and_execute import PlanAndExecute, load_agent_executor, load_chat_planner
from langchain.tools.python.tool import PythonREPLTool
from langchain.llms import OpenAI
from langchain import SerpAPIWrapper
from langchain.agents.tools import Tool
from langchain.tools import tool
from langchain import LLMMathChain

@tool
def search_for_flights(originLocationCode: str, destinationLocationCode: str, departureDate: datetime, num_adults: int) -> list:
    """Sends get request to Amadeus flights API given parameters"""
    
    # Assuming you've defined api_key and api_secret somewhere else
    amadeus = Client(client_id=api_key, client_secret=api_secret)

    # Defining the parameters for the flight
    params = {
        'originLocationCode': originLocationCode,
        'destinationLocationCode': destinationLocationCode,
        'departureDate': departureDate.strftime('%Y-%m-%d'),  # API might require specific date format
        'adults': num_adults
        # add or modify other parameters according to your needs
    }
    
    try:
        response_flights = amadeus.shopping.flight_offers_search.get(**params)
        
    except ResponseError as error:
        print(f"ResponseError occurred: {error}")
        print(f"Error code: {error.code}")
        print(f"Error message: {error.description}")
        return []  # return an empty list in case of an error

    return response_flights.data

# %%
from langchain.agents import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType

agent = create_pandas_dataframe_agent(
    ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613", openai_api_key="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"),
    df_flights,
    verbose=True,
    agent_type=AgentType.OPENAI_FUNCTIONS,
)

agent.run("what's the cheapest flight?")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\openai_functions_agent\base.py:113, in _parse_ai_message(message)
#     112 try:
# --> 113     _tool_input = json.loads(function_call["arguments"])
#     114 except JSONDecodeError:
#
# File ~\anaconda3\envs\flight_env\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\envs\flight_env\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\envs\flight_env\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[25], line 12
#       3 from langchain.agents.agent_types import AgentType
#       5 agent = create_pandas_dataframe_agent(
#       6     ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613", openai_api_key="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"),
#       7     df_flights,
#       8     verbose=True,
#       9     agent_type=AgentType.OPENAI_FUNCTIONS,
#      10 )
# ---> 12 agent.run("what's the cheapest flight?")
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\chains\base.py:440, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     438     if len(args) != 1:
#     439         raise ValueError("`run` supports only one positional argument.")
# --> 440     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     441         _output_key
#     442     ]
#     444 if kwargs and not args:
#     445     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     446         _output_key
#     447     ]
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\chains\base.py:243, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
# --> 243     raise e
#     244 run_manager.on_chain_end(outputs)
#     245 final_outputs: Dict[str, Any] = self.prep_outputs(
#     246     inputs, outputs, return_only_outputs
#     247 )
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\chains\base.py:237, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     231 run_manager = callback_manager.on_chain_start(
#     232     dumpd(self),
#     233     inputs,
#     234 )
#     235 try:
#     236     outputs = (
# --> 237         self._call(inputs, run_manager=run_manager)
#     238         if new_arg_supported
#     239         else self._call(inputs)
#     240     )
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\agent.py:994, in AgentExecutor._call(self, inputs, run_manager)
#     992 # We now enter the agent loop (until it returns something).
#     993 while self._should_continue(iterations, time_elapsed):
# --> 994     next_step_output = self._take_next_step(
#     995         name_to_tool_map,
#     996         color_mapping,
#     997         inputs,
#     998         intermediate_steps,
#     999         run_manager=run_manager,
#    1000     )
#    1001     if isinstance(next_step_output, AgentFinish):
#    1002         return self._return(
#    1003             next_step_output, intermediate_steps, run_manager=run_manager
#    1004         )
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\agent.py:808, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     806     raise_error = False
#     807 if raise_error:
# --> 808     raise e
#     809 text = str(e)
#     810 if isinstance(self.handle_parsing_errors, bool):
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\agent.py:797, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     794     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#     796     # Call the LLM to see what to do.
# --> 797     output = self.agent.plan(
#     798         intermediate_steps,
#     799         callbacks=run_manager.get_child() if run_manager else None,
#     800         **inputs,
#     801     )
#     802 except OutputParserException as e:
#     803     if isinstance(self.handle_parsing_errors, bool):
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\openai_functions_agent\base.py:222, in OpenAIFunctionsAgent.plan(self, intermediate_steps, callbacks, with_functions, **kwargs)
#     217 else:
#     218     predicted_message = self.llm.predict_messages(
#     219         messages,
#     220         callbacks=callbacks,
#     221     )
# --> 222 agent_decision = _parse_ai_message(predicted_message)
#     223 return agent_decision
#
# File ~\anaconda3\envs\flight_env\lib\site-packages\langchain\agents\openai_functions_agent\base.py:115, in _parse_ai_message(message)
#     113     _tool_input = json.loads(function_call["arguments"])
#     114 except JSONDecodeError:
# --> 115     raise OutputParserException(
#     116         f"Could not parse tool input: {function_call} because "
#     117         f"the `arguments` is not valid JSON."
#     118     )
#     120 # HACK HACK HACK:
#     121 # The code that encodes tool input into Open AI uses a special variable
#     122 # name called `__arg1` to handle old style tools that do not expose a
#     123 # schema and expect a single string argument as an input.
#     124 # We unpack the argument here if it exists.
#     125 # Open AI does not support passing in a JSON array as an argument.
#     126 if "__arg1" in _tool_input:
#
# OutputParserException: Could not parse tool input: {'name': 'python', 'arguments': "cheapest_flight = df[df['price.total'] == df['price.total'].min()]\ncheapest_flight"} because the `arguments` is not valid JSON.

# %%
agent_executor = create_python_agent(
    llm=OpenAI(temperature=0, openai_api_key="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"),
    tool=PythonREPLTool(),
    verbose=True,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
)

# %%
# agent_executor.run("what's the cheapest flight")

# %%
df_flights.to_csv("../src.flights.csv")

# %%
# Load the data into a DataFrame
df = pd.DataFrame(response_flights.data)

# Extract itineraries, validatingAirlineCodes, price (total and currency) and id into separate dataframes
df_itineraries = df[['id', 'itineraries']].explode('itineraries').reset_index(drop=True)

# In the itineraries column, each cell is a dictionary. So, we need to convert those dictionaries into separate columns.
df_itineraries = df_itineraries.join(pd.json_normalize(df_itineraries['itineraries'])).drop(columns='itineraries')

# At this point, 'segments' column is a list of dictionaries where each dictionary represents a leg of the journey.
# We want each leg to be a separate row in the dataframe. So, explode the 'segments' column.
df_itineraries = df_itineraries.explode('segments').reset_index(drop=True)

# Add a 'leg_id' column to identify each leg of the journey
df_itineraries['leg_id'] = df_itineraries.groupby('id').cumcount() + 1

# Now, convert the dictionaries in the 'segments' column into separate columns
df_segments = pd.json_normalize(df_itineraries['segments'])

# To avoid overlapping columns, add a prefix to the column names of the new dataframe
df_segments.columns = ['flight_' + str(col) for col in df_segments.columns]

# Now join the original dataframe with the new one
df_itineraries = df_itineraries.join(df_segments).drop(columns='segments')

df_validatingAirlineCodes = df[['id', 'validatingAirlineCodes']]

# For the price column, we only need total and currency. So, extract only those into a new dataframe
df_price = df['price'].apply(pd.Series)[['total', 'currency']]
df_price['id'] = df['id']

# Now join these dataframes on the 'id' column
df_journeys = pd.merge(df_itineraries, df_validatingAirlineCodes, on='id')
df_journeys = pd.merge(df_journeys, df_price, on='id')

# Create a new column for the total number of legs per journey
df_journeys['total_legs'] = df_journeys.groupby('id')['leg_id'].transform('max')

df_journeys = df_journeys.merge(right=df_airline_codes, how='left', left_on="flight_operating.carrierCode", right_on="iataCode")

df_journeys.rename(columns={"id":"journey_id"}, inplace=True)
df_journeys.drop(columns=["flight_id", "validatingAirlineCodes"], inplace=True)

df_journeys
# Out:
#     journey_id  duration  leg_id flight_carrierCode flight_number  \
# 0            1  PT24H15M       1                 TR             3
# 1            1  PT24H15M       2                 TR           624
# 2            2  PT28H40M       1                 TR             3
# 3            2  PT28H40M       2                 TR           604
# 4            3   PT16H5M       1                 TR            13
# ..         ...       ...     ...                ...           ...
# 122         63  PT29H35M       2                 NH           805
# 123         64  PT30H20M       1                 NH           880
# 124         64  PT30H20M       2                 NH           803
# 125         65  PT21H45M       1                 NH           880
# 126         65  PT21H45M       2                 NH           847
#
#     flight_duration  flight_numberOfStops  flight_blacklistedInEU  \
# 0           PT8H20M                     0                   False
# 1           PT2H30M                     0                   False
# 2           PT8H20M                     0                   False
# 3           PT2H35M                     0                   False
# 4           PT8H25M                     0                   False
# ..              ...                   ...                     ...
# 122         PT6H45M                     0                   False
# 123         PT9H40M                     0                   False
# 124         PT7H25M                     0                   False
# 125         PT9H40M                     0                   False
# 126         PT6H40M                     0                   False
#
#     flight_departure.iataCode flight_departure.terminal  ...  \
# 0                         SYD                         1  ...
# 1                         SIN                         1  ...
# 2                         SYD                         1  ...
# 3                         SIN                         1  ...
# 4                         SYD                         1  ...
# ..                        ...                       ...  ...
# 122                       NRT                         1  ...
# 123                       SYD                         1  ...
# 124                       NRT                         1  ...
# 125                       SYD                         1  ...
# 126                       HND                       NaN  ...
#
#     flight_operating.carrierCode flight_stops    total currency total_legs  \
# 0                             TR          NaN   250.85      EUR          2
# 1                             TR          NaN   250.85      EUR          2
# 2                             TR          NaN   292.85      EUR          2
# 3                             TR          NaN   292.85      EUR          2
# 4                             TR          NaN   294.85      EUR          2
# ..                           ...          ...      ...      ...        ...
# 122                           NH          NaN  5922.11      EUR          2
# 123                           NH          NaN  5922.11      EUR          2
# 124                           NH          NaN  5922.11      EUR          2
# 125                           NH          NaN  5963.48      EUR          2
# 126                           NH          NaN  5963.48      EUR          2
#
#         type iataCode icaoCode        businessName  commonName
# 0    airline       TR      TGW               SCOOT       SCOOT
# 1    airline       TR      TGW               SCOOT       SCOOT
# 2    airline       TR      TGW               SCOOT       SCOOT
# 3    airline       TR      TGW               SCOOT       SCOOT
# 4    airline       TR      TGW               SCOOT       SCOOT
# ..       ...      ...      ...                 ...         ...
# 122  airline       NH      ANA  ALL NIPPON AIRWAYS  ALL NIPPON
# 123  airline       NH      ANA  ALL NIPPON AIRWAYS  ALL NIPPON
# 124  airline       NH      ANA  ALL NIPPON AIRWAYS  ALL NIPPON
# 125  airline       NH      ANA  ALL NIPPON AIRWAYS  ALL NIPPON
# 126  airline       NH      ANA  ALL NIPPON AIRWAYS  ALL NIPPON
#
# [127 rows x 25 columns]

# %%
test = df_final.sort_values(by='id')
test.to_csv("../src/flights.csv")

# %%
test2 = test.merge(right=df_airline_codes, how='left', left_on="flight_operating.carrierCode", right_on="iataCode")
test2
# Out:
#      id  duration  leg_id flight_carrierCode flight_number flight_duration  \
# 0     1  PT24H15M       1                 TR             3         PT8H20M
# 1     1  PT24H15M       2                 TR           624         PT2H30M
# 2    10  PT14H20M       2                 ID          7637         PT4H15M
# 3    10  PT14H20M       1                 ID          6006         PT6H25M
# 4    11  PT14H15M       2                 PR           732         PT3H30M
# ..   ..       ...     ...                ...           ...             ...
# 122   7  PT31H55M       2                 TR           610         PT2H30M
# 123   8  PT33H25M       1                 TR             3         PT8H20M
# 124   8  PT33H25M       2                 TR           616         PT2H30M
# 125   9  PT31H10M       2                 OD           520         PT2H10M
# 126   9  PT31H10M       1                 OD           172         PT9H50M
#
#     flight_id  flight_numberOfStops  flight_blacklistedInEU  \
# 0          41                     0                   False
# 1          42                     0                   False
# 2          53                     0                   False
# 3          52                     0                   False
# 4          34                     0                   False
# ..        ...                   ...                     ...
# 122       127                     0                   False
# 123        62                     0                   False
# 124        63                     0                   False
# 125        28                     0                   False
# 126        27                     1                   False
#
#     flight_departure.iataCode  ...  \
# 0                         SYD  ...
# 1                         SIN  ...
# 2                         DPS  ...
# 3                         SYD  ...
# 4                         MNL  ...
# ..                        ...  ...
# 122                       SIN  ...
# 123                       SYD  ...
# 124                       SIN  ...
# 125                       KUL  ...
# 126                       SYD  ...
#
#                                           flight_stops validatingAirlineCodes  \
# 0                                                  NaN                   [SQ]
# 1                                                  NaN                   [SQ]
# 2                                                  NaN                   [GP]
# 3                                                  NaN                   [GP]
# 4                                                  NaN                   [PR]
# ..                                                 ...                    ...
# 122                                                NaN                   [SQ]
# 123                                                NaN                   [SQ]
# 124                                                NaN                   [SQ]
# 125                                                NaN                   [GP]
# 126  [{'iataCode': 'DPS', 'duration': 'PT1H', 'arri...                   [GP]
#
#       total currency total_legs     type iataCode icaoCode  \
# 0    250.85      EUR          2  airline       TR      TGW
# 1    250.85      EUR          2  airline       TR      TGW
# 2    342.74      EUR          2  airline       ID      BTK
# 3    342.74      EUR          2  airline       ID      BTK
# 4    345.27      EUR          2  airline       PR      PAL
# ..      ...      ...        ...      ...      ...      ...
# 122  315.85      EUR          2  airline       TR      TGW
# 123  315.85      EUR          2  airline       TR      TGW
# 124  315.85      EUR          2  airline       TR      TGW
# 125  323.62      EUR          2  airline       OD      MXD
# 126  323.62      EUR          2  airline       OD      MXD
#
#             businessName           commonName
# 0                  SCOOT                SCOOT
# 1                  SCOOT                SCOOT
# 2    BATIK AIR INDONESIA  BATIK AIR INDONESIA
# 3    BATIK AIR INDONESIA  BATIK AIR INDONESIA
# 4    PHILIPPINE AIRLINES        PHILIPPINE AL
# ..                   ...                  ...
# 122                SCOOT                SCOOT
# 123                SCOOT                SCOOT
# 124                SCOOT                SCOOT
# 125   BATIK AIR MALAYSIA   BATIK AIR MALAYSIA
# 126   BATIK AIR MALAYSIA   BATIK AIR MALAYSIA
#
# [127 rows x 27 columns]
